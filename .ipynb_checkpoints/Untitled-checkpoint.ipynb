# %% [markdown]
# This script will be used as a template to explore data sets

# %%
# import libraries
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

# %%
#read the csv file 
data_set=pd.read_csv('pop_data.csv');

# %%
data_set.head()
yoi=data_set.loc[[4,5,6,7,8,9,11,15,20]]
yoi.loc[:,['year','total','total_local','total_nlocal']]
yoi.index[1]
yoi['g_rate']=yoi['total'].apply(lambda x: x['total']/yoi[x.index-1,['total']])
yoi['g_rate']
# Out:
#   File "<ipython-input-95-3636c1767ff5>", line 5
#     yoi['g_rate']=yoi.apply(lambda x['total']: x['total']/yoi[x.index-1,['total']])
#                                     ^
# SyntaxError: invalid syntax

# %%
#Population total data
sdata=data_set[4:]
sdata[['year','male_local']]
total =data_set.loc[:,['year','total']];

local=data_set[2:]
local=local.loc[:,['year','total_local']];


nlocal=data_set[2:]
nlocal=nlocal.loc[:,['year','total_nlocal']];

# %%
# Plotting Line graph
plt.plot(total['year'],total['total'])
plt.plot(local['year'],local['total_local'])
plt.plot(nlocal['year'],nlocal['total_nlocal'])




#plt.yscale('linear')
plt.title('population')
# Out:
# Text(0.5,1,'population')
